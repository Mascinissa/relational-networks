# %%
# !git clone https://github.com/Mascinissa/relational-networks
# Out:
# Cloning into 'relational-networks'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 163 (delta 3), reused 7 (delta 1), pack-reused 154
# Receiving objects: 100% (163/163), 57.86 MiB | 17.07 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
cd relational-networks
# Out:
# /content/relational-networks

# %% [markdown]
# ## Generating the image version of the sort-of-CLEVR dataset

# %%
# !python SoCLEVR_images_generator.py
# Out:
# directory ./data already exists
# building test datasets...
# building train datasets...
# saving datasets...
# datasets saved at ./data/sort-of-clevr.pickle

# %% [markdown]
# ## Training the RN model on the image version of the sort-of-CLEVR dataset

# %%
# !python train_SoCLEVR_images.py
# Out:
# loading data...
# processing data...
# directory ./model already exists
# Epoch  1 / 40
# 100% 1531/1531 [01:08<00:00, 22.40it/s]
# Train set: Relation accuracy: 67% | Non-relation accuracy: 55%
# Test set: Relation accuracy: 68% | Non-relation accuracy: 54%
#
# Epoch  2 / 40
# 100% 1531/1531 [01:05<00:00, 23.32it/s]
# Train set: Relation accuracy: 70% | Non-relation accuracy: 55%
# Test set: Relation accuracy: 71% | Non-relation accuracy: 55%
#
# Epoch  3 / 40
# 100% 1531/1531 [01:05<00:00, 23.38it/s]
# Train set: Relation accuracy: 69% | Non-relation accuracy: 56%
# Test set: Relation accuracy: 69% | Non-relation accuracy: 54%
#
# Epoch  4 / 40
# 100% 1531/1531 [01:05<00:00, 23.45it/s]
# Train set: Relation accuracy: 71% | Non-relation accuracy: 55%
# Test set: Relation accuracy: 72% | Non-relation accuracy: 53%
#
# Epoch  5 / 40
# 100% 1531/1531 [01:04<00:00, 23.59it/s]
# Train set: Relation accuracy: 71% | Non-relation accuracy: 56%
# ...

# %% [markdown]
# ## Generating the state description version of the sort-of-CLEVR dataset

# %%
# !python SoCLEVR_state_description_generator.py
# Out:
# directory ./data already exists
# building test datasets...
# building train datasets...
# printing random samples  from the training set of state description tables
#    instance_id   color   X   Y   shape
# 0            0     red  10  19  circle
# 1            0   green  36  48  square
# 2            0    blue   7  33  square
# 3            0  orange  17  48  circle
# 4            0    gray  43  61  circle
# 5            0  yellow  21  31  square
#
#
#    instance_id   color   X   Y   shape
# 0            1     red  60  10  circle
# 1            1   green  17  37  circle
# 2            1    blue  20  55  square
# 3            1  orange  63  59  square
# 4            1    gray   8  48  square
# 5            1  yellow  36  12  square
#
#
#    instance_id   color   X   Y   shape
# 0            2     red  35  23  square
# 1            2   green  46   5  square
# 2            2    blue  25  63  circle
# 3            2  orange   9  54  square
# 4            2    gray  66  57  circle
# ...

# %% [markdown]
# ## Training the RN model on the state description version of the sort-of-CLEVR dataset

# %%
# !python train_SoCLEVR_state_description.py
# Out:
# loading data...
# processing data...
# directory ./model already exists
# Epoch  1 / 40
# 100% 1531/1531 [00:17<00:00, 88.38it/s]
# Train set: Relation accuracy: 44% | Non-relation accuracy: 57%
# Test set: Relation accuracy: 44% | Non-relation accuracy: 59%
#
# Epoch  2 / 40
# 100% 1531/1531 [00:16<00:00, 92.56it/s]
# Train set: Relation accuracy: 70% | Non-relation accuracy: 62%
# Test set: Relation accuracy: 72% | Non-relation accuracy: 62%
#
# Epoch  3 / 40
# 100% 1531/1531 [00:16<00:00, 92.56it/s]
# Train set: Relation accuracy: 71% | Non-relation accuracy: 63%
# Test set: Relation accuracy: 72% | Non-relation accuracy: 64%
#
# Epoch  4 / 40
# 100% 1531/1531 [00:16<00:00, 92.67it/s]
# Train set: Relation accuracy: 71% | Non-relation accuracy: 63%
# Test set: Relation accuracy: 73% | Non-relation accuracy: 63%
#
# Epoch  5 / 40
# 100% 1531/1531 [00:16<00:00, 91.30it/s]
# Train set: Relation accuracy: 73% | Non-relation accuracy: 63%
# ...
